# %% [markdown]
# # Task 2
# Showing the change of output image during the training procedure

# %%
from PIL import Image

# %%
print('Beginning: 0, 1000, 2000, 3000')

display(Image.open("./images/0.png"))
display(Image.open("./images/1000.png"))
display(Image.open("./images/2000.png"))
display(Image.open("./images/3000.png"))
# Out:
# Beginning: 0, 1000, 2000, 3000
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A600453A58>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A600453A58>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A600453828>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A600453A90>

# %%
print('Middle: 93000, 94000, 95000')

display(Image.open("./images/93000.png"))
display(Image.open("./images/94000.png"))
display(Image.open("./images/95000.png"))
# Out:
# Middle: 93000, 94000, 95000
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A67FDD0C18>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A67FDD07B8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A67FDD0C88>

# %%
print('End: 185000, 186000, 187000')

display(Image.open("./images/185000.png"))
display(Image.open("./images/186000.png"))
display(Image.open("./images/187000.png"))
# Out:
# End: 185000, 186000, 187000
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A67FFE37B8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A67FFE3358>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=152x152 at 0x1A67FFE3208>
